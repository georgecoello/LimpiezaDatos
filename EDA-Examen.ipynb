# %%
import pandas as pd

# %%
card = pd.read_csv("BankChurners.csv")

# %%
card
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# 0                  39  ...       12691.0                  777
# 1                  44  ...        8256.0                  864
# 2                  36  ...        3418.0                    0
# 3                  34  ...        3313.0                 2517
# 4                  21  ...        4716.0                    0
# ...               ...  ...           ...                  ...
# 10122              40  ...        4003.0                 1851
# 10123              25  ...        4277.0                 2186
# 10124              36  ...        5409.0                    0
# 10125              36  ...        5281.0                    0
# 10126              25  ...       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
# [10127 rows x 23 columns]

# %%
card.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# CLIENTNUM: 10127 valores
# Attrition_Flag:
#     Existing Customer    8500
#     Attrited Customer    1627
# Customer_Age: 26-73
# Gender: M F
# F    5358
# M    4769
# Dependent_count: 0-5
# Education_Level:
#     Graduate         3128
#     High School      2013
#     Unknown          1519
#     Uneducated       1487
#     College          1013
#     Post-Graduate     516
#     Doctorate         451
# Marital_Status:
#     Married     4687
#     Single      3943
#     Unknown      749
#     Divorced     748
# Income_Category:
#     Less than $40K    3561
#     $40K - $60K       1790
#     $80K - $120K      1535
#     $60K - $80K       1402
#     Unknown           1112
#     $120K +            727
# Card_Category:
#     Blue        9436
#     Silver       555
#     Gold         116
#     Platinum      20
# Months_on_book: 13-56
# Total_Relationship_Count: 1-6
#     3    2305
#     4    1912
#     5    1891
#     6    1866
#     2    1243
#     1     910
# Months_Inactive_12_mon: 0-6
#     3    3846
#     2    3282
#     1    2233
#     4     435
#     5     178
#     6     124
#     0      29
# Contacts_Count_12_mon: 0-6
#     3    3380
#     2    3227
#     1    1499
#     4    1392
#     0     399
#     5     176
#     6      54
# Credit_Limit: 1440 - 34500
# Total_Revolving_Bal: 0- 2517
# Avg_Open_To_Buy: 0-¿3-34500
# Total_Amt_Chng_Q4_Q1:0 - 3.4
# Total_Trans_Amt: 510 - 18500
# Total_Trans_Ct: 10-139
# Total_Ct_Chng_Q4_Q1: 0 - 3.71
# Avg_Utilization_Ratio: 0-1
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1: 0-1
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2: 0-1

# %% [markdown]
# Variables Nulas

# %%
card.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age_x                                                                                                                        0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# Income_Category                                                                                                                       0
# Card_Category                                                                                                                         0
# Months_on_book                                                                                                                        0
# Total_Relationship_Count                                                                                                              0
# Months_Inactive_12_mon                                                                                                                0
# Contacts_Count_12_mon                                                                                                                 0
# Credit_Limit                                                                                                                          0
# Total_Revolving_Bal                                                                                                                   0
# Avg_Open_To_Buy                                                                                                                       0
# Total_Amt_Chng_Q4_Q1                                                                                                                  0
# Total_Trans_Amt                                                                                                                       0
# Total_Trans_Ct                                                                                                                        0
# Total_Ct_Chng_Q4_Q1                                                                                                                   0
# Avg_Utilization_Ratio                                                                                                                 0
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1    0
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2    0
# Customer_Age_y                                                                                                                        0
# Percent                                                                                                                               0
# Education_t                                                                                                                           0
# dtype: int64

# %% [markdown]
# - En caso de que la columna tenga mas del 90% de valores nulos excluir
# En base al análisis hecho anteriormente no hay ningún valor nulo, por tanto, no se excluye ninguna columna
# - En caso de variable numérica buscar una buena estratificación
# Al no haber valores nulos no se hace el cambio por la mediana
# - En caso de variables categoricas
# En las variables categóricas de igual manera no se encuentran valores nulos
#
# //No se toma en cuenta el 0 como valor nulo porque se piensa que puede representar un dato importante para la empresa y no se quiere dañar el sentido de la información brindada

# %% [markdown]
# Variables Numéricas
# ==

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Columnas con valores atípicos:
# Months_on_book
# Customer_Age_x
# Months_Inactive_12_mon
# Contacts_Count_12_mon
# Credit_Limit //Con este se hará la estratificiación
# Avg_Open_To_Buy
# Total_Amt_Chng_Q4_Q1
# Total_Trans_Amt
# Total_Ct_Chng_Q4_Q1
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2

# %%
columns = ['CLIENTNUM', 'Attrition_Flag', 'Gender', 'Customer_Age_x',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
       'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
       'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']

# %%
card.loc[:,columns].select_dtypes('int64').columns
# Out:
# Index(['CLIENTNUM', 'Customer_Age_x', 'Dependent_count', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Total_Revolving_Bal', 'Total_Trans_Amt',
#        'Total_Trans_Ct'],
#       dtype='object')

# %%
card.loc[:,columns].select_dtypes('float64').columns
# Out:
# Index(['Credit_Limit', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1',
#        'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# No se tomarán en cuenta las columnas (se cree que son varibles que representan respuesta a otras columnas):
# - Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1
# - Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2

# %% [markdown]
# Se hará la estratificación en base a Credit Limit, porque se considera que es la columna con más valores atípicos

# %%
plt.boxplot(card["Credit_Limit"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bb7c212430>,
#   <matplotlib.lines.Line2D at 0x1bb7c212700>],
#  'caps': [<matplotlib.lines.Line2D at 0x1bb7c2129d0>,
#   <matplotlib.lines.Line2D at 0x1bb7c212ca0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1bb7c212160>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bb7c212f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bb7c218280>],
#  'means': []}

# %%
sns.boxplot(data = card.loc[ (card['Gender'] == 'M'), : ], x= 'Card_Category', y ='Credit_Limit' )
# Out:
# <AxesSubplot:xlabel='Card_Category', ylabel='Credit_Limit'>

# %%
card["Card_Category"].value_counts()
# Out:
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
limit_b = card.loc[(card["Gender"] == "M") & (card["Card_Category"] == "Blue"), ["Credit_Limit"]]
limit_b
# Out:
#        Credit_Limit
# 0           12691.0
# 3            3193.0
# 4            4470.0
# 5           14784.0
# 6            4785.0
# ...             ...
# 10115       27124.0
# 10116       22715.0
# 10119        3676.0
# 10122       10292.0
# 10126        4552.0
#
# [4335 rows x 1 columns]

# %%
plt.boxplot(limit_b)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bb7ea84280>,
#   <matplotlib.lines.Line2D at 0x1bb7ea84550>],
#  'caps': [<matplotlib.lines.Line2D at 0x1bb7ea84820>,
#   <matplotlib.lines.Line2D at 0x1bb7ea84af0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1bb7ea79f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bb7ea84dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bb7ea8f0d0>],
#  'means': []}

# %%
q1 = np.quantile(limit,0.25)
q1
# Out:
# 3534.5

# %%
q3 = np.quantile(limit,0.75)
q3
# Out:
# 15602.0

# %%
q2 = np.median(limit)
q2
# Out:
# 7685.0

# %%
iqr = q3-q1
iqr
# Out:
# 12067.5

# %%
#Veremos los valores atípicos superiores
upper = q3 + (1.5*iqr)
upper
# Out:
# 33703.25

# %%
#Veremos los valores atípicos inferiores
lower = q1 - (1.5*iqr)
lower
# Out:
# -14566.75

# %% [markdown]
# Al ser de valor negativo no se tomará en cuenta los valores atípicos inferiores, incluso lo podemos notar en la gráfica que no se encuentran este tipo de valores

# %%
limit_b.loc[(limit["Credit_Limit"] > upper) & (limit["Credit_Limit"] > lower), :]
# Out:
#        Credit_Limit
# 44          34516.0
# 79          34516.0
# 110         34516.0
# 137         34516.0
# 255         34516.0
# ...             ...
# 9830        34516.0
# 10080       34516.0
# 10082       34516.0
# 10086       34516.0
# 10112       34516.0
#
# [213 rows x 1 columns]

# %% [markdown]
# Estratificación

# %%
dfq1 = card.loc[:,["Gender","Card_Category","Credit_Limit"]].groupby(["Gender","Card_Category"],as_index=False).quantile(0.25)
dfq1.columns = ["Gender","Card_Category","Credit_B1"]

# %%
dfq3 = card.loc[:,["Gender","Card_Category","Credit_Limit"]].groupby(["Gender","Card_Category"],as_index=False).quantile(0.75)
dfq3.columns = ["Gender","Card_Category","Credit_B3"]

# %%
dfq2 = card.loc[:,["Gender","Card_Category","Credit_Limit"]].groupby(["Gender","Card_Category"],as_index=False).quantile(0.50)
dfq2.columns = ["Gender","Card_Category","Credit_B2"]
dfq2
# Out:
#   Gender Card_Category  Credit_B2
# 0      F          Blue     2945.0
# 1      F          Gold    15987.0
# 2      F      Platinum    34516.0
# 3      F        Silver    14320.0
# 4      M          Blue     7685.0
# 5      M          Gold    34516.0
# 6      M      Platinum    34516.0
# 7      M        Silver    34516.0

# %%
df_iqr = dfq1.merge(dfq3, on = ["Gender", "Card_Category"], how = "inner").merge(dfq2, on = ["Gender", "Card_Category"], how = "inner")
df_iqr["IQR"] = df_iqr.apply(lambda r: r["Credit_B3"] - r["Credit_B1"], axis=1)
df_iqr["Upper"] = df_iqr.apply(lambda j: (j["Credit_B3"] + 1.5*j["IQR"]), axis=1)
df_iqr["Lower"] = df_iqr.apply(lambda j: (j["Credit_B1"] - 1.5*j["IQR"]), axis=1)
df_iqr
# Out:
#   Gender Card_Category  Credit_B1  Credit_B3  Credit_B2       IQR      Upper  \
# 0      F          Blue    2112.00     5076.0     2945.0   2964.00   9522.000
# 1      F          Gold   15774.75    23981.0    15987.0   8206.25  36290.375
# 2      F      Platinum   15987.00    34516.0    34516.0  18529.00  62309.500
# 3      F        Silver   12048.25    21979.0    14320.0   9930.75  36875.125
# 4      M          Blue    3534.50    15602.0     7685.0  12067.50  33703.250
# 5      M          Gold   34516.00    34516.0    34516.0      0.00  34516.000
# 6      M      Platinum   34516.00    34516.0    34516.0      0.00  34516.000
# 7      M        Silver   26142.00    34516.0    34516.0   8374.00  47077.000
#
#        Lower
# 0  -2334.000
# 1   3465.375
# 2 -11806.500
# 3  -2847.875
# 4 -14566.750
# 5  34516.000
# 6  34516.000
# 7  13581.000

# %%
card_t = card.merge(df_iqr, on = ["Gender", "Card_Category"], how = "left").copy()
card_t.shape
# Out:
# (10127, 32)

# %%
def getCredit(r):
    if ((r["Credit_Limit"] <= r["Lower"]) or (r["Credit_Limit"]>= r["Upper"])):
        return r["Credit_B2"]
    else:
        return r["Credit_Limit"]

# %%
card_t["New_Credit"] = card_t.apply(lambda r: getCredit(r), axis = 1)
card_t
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age_x Gender  Dependent_count  \
# 0      768805383  Existing Customer              45      M                3
# 1      769911858  Existing Customer              40      F                4
# 2      818906208  Existing Customer              32      M                0
# 3      806160108  Existing Customer              61      M                1
# 4      784725333  Existing Customer              41      M                3
# ...          ...                ...             ...    ...              ...
# 10122  780097533  Existing Customer              48      M                3
# 10123  714677583  Attrited Customer              50      F                3
# 10124  816517683  Existing Customer              38      F                2
# 10125  779134458  Attrited Customer              33      F                1
# 10126  771982083  Existing Customer              44      M                4
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1         High School        Unknown  Less than $40K          Blue
# 2         High School        Unknown     $60K - $80K        Silver
# 3         High School        Married     $40K - $60K          Blue
# 4         High School        Married     $40K - $60K          Blue
# ...               ...            ...             ...           ...
# 10122       Doctorate       Divorced    $80K - $120K          Blue
# 10123       Doctorate         Single         Unknown          Blue
# 10124       Doctorate        Married  Less than $40K          Blue
# 10125       Doctorate         Single  Less than $40K          Blue
# 10126       Doctorate        Married    $80K - $120K          Blue
#
#        Months_on_book  ...  Customer_Age_y   Percent  Education_t  Credit_B1  \
# 0                  39  ...            2013  0.198776  High School     3534.5
# 1                  34  ...            2013  0.198776  High School     2112.0
# 2                  27  ...            2013  0.198776  High School    26142.0
# 3                  56  ...            2013  0.198776  High School     3534.5
# 4                  33  ...            2013  0.198776  High School     3534.5
# ...               ...  ...             ...       ...          ...        ...
# 10122              33  ...             451  0.044534       Others     3534.5
# 10123              36  ...             451  0.044534       Others     2112.0
# 10124              33  ...             451  0.044534       Others     2112.0
# 10125              15  ...             451  0.044534       Others     2112.0
# 10126              33  ...             451  0.044534       Others     3534.5
#
#        Credit_B3  Credit_B2      IQR     Upper     Lower  New_Credit
# 0        15602.0     7685.0  12067.5  33703.25 -14566.75     12691.0
# 1         5076.0     2945.0   2964.0   9522.00  -2334.00      3313.0
# 2        34516.0    34516.0   8374.0  47077.00  13581.00     29081.0
# 3        15602.0     7685.0  12067.5  33703.25 -14566.75      3193.0
# 4        15602.0     7685.0  12067.5  33703.25 -14566.75      4470.0
# ...          ...        ...      ...       ...       ...         ...
# 10122    15602.0     7685.0  12067.5  33703.25 -14566.75     10292.0
# 10123     5076.0     2945.0   2964.0   9522.00  -2334.00      5173.0
# 10124     5076.0     2945.0   2964.0   9522.00  -2334.00      7530.0
# 10125     5076.0     2945.0   2964.0   9522.00  -2334.00      3709.0
# 10126    15602.0     7685.0  12067.5  33703.25 -14566.75      4552.0
#
# [10127 rows x 33 columns]

# %%
sns.boxplot(data = card_t.loc[ (card_t['Gender'] == 'M'), : ], x= 'Card_Category', y ='New_Credit' )
# Out:
# <AxesSubplot:xlabel='Card_Category', ylabel='New_Credit'>

# %%
sns.boxplot(data = card.loc[ (card['Gender'] == 'M'), : ], x= 'Card_Category', y ='Credit_Limit' )
# Out:
# <AxesSubplot:xlabel='Card_Category', ylabel='Credit_Limit'>

# %%
sns.boxplot(data = card.loc[ (card['Gender'] == 'F'), : ], x= 'Card_Category', y ='Credit_Limit' )
# Out:
# <AxesSubplot:xlabel='Card_Category', ylabel='Credit_Limit'>

# %% [markdown]
# Variables Categóricas
# - Columnas con texto como contenido:
# *Attrition_Flag
# *Gender
# *Education_Level
# *Marital_Status
# *Income_Category
# *Card_Category

# %% [markdown]
# Varibales Categoricas

# %%
cols = ['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category']

# %%
valids = []
many = []
one = []

size = card.shape[0]
umbral = 0.9

# %%
for c in cols : 
    level = card.loc[:,cols].drop_duplicates().shape[0]
    if (level/size) > umbral: 
        many.append(c)
    elif level == 1: 
        one.append(c)
    else: 
        valids.append(c)

# %%
valids
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %% [markdown]
# Se hará el reemplazo con Education_Level

# %%
level = card.groupby(["Education_Level"], as_index = False).agg({"Customer_Age":["count"]})

# %%
level.columns = level.columns.droplevel(1)

# %%
level
# Out:
#   Education_Level  Customer_Age
# 0         College          1013
# 1       Doctorate           451
# 2        Graduate          3128
# 3     High School          2013
# 4   Post-Graduate           516
# 5      Uneducated          1487
# 6         Unknown          1519

# %%
level["Percent"] = level["Customer_Age"]/size

# %%
level.sort_values(["Percent"], ascending = False)
# Out:
#   Education_Level  Customer_Age   Percent
# 2        Graduate          3128  0.308877
# 3     High School          2013  0.198776
# 6         Unknown          1519  0.149995
# 5      Uneducated          1487  0.146835
# 0         College          1013  0.100030
# 4   Post-Graduate           516  0.050953
# 1       Doctorate           451  0.044534

# %%
level["Education_t"] = "Others"

# %%
level["Education_t"] = level.apply(lambda r: r["Education_Level"] if r["Percent"] > 0.1 else r["Education_t"], axis=1)

# %%
level.loc[:,["Education_Level", "Education_t"]]
# Out:
#   Education_Level  Education_t
# 0         College      College
# 1       Doctorate       Others
# 2        Graduate     Graduate
# 3     High School  High School
# 4   Post-Graduate       Others
# 5      Uneducated   Uneducated
# 6         Unknown      Unknown

# %%
card = card.merge(level, on= ["Education_Level"], how = "inner")

# %%
card
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age_x Gender  Dependent_count  \
# 0      768805383  Existing Customer              45      M                3
# 1      769911858  Existing Customer              40      F                4
# 2      818906208  Existing Customer              32      M                0
# 3      806160108  Existing Customer              61      M                1
# 4      784725333  Existing Customer              41      M                3
# ...          ...                ...             ...    ...              ...
# 10122  780097533  Existing Customer              48      M                3
# 10123  714677583  Attrited Customer              50      F                3
# 10124  816517683  Existing Customer              38      F                2
# 10125  779134458  Attrited Customer              33      F                1
# 10126  771982083  Existing Customer              44      M                4
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1         High School        Unknown  Less than $40K          Blue
# 2         High School        Unknown     $60K - $80K        Silver
# 3         High School        Married     $40K - $60K          Blue
# 4         High School        Married     $40K - $60K          Blue
# ...               ...            ...             ...           ...
# 10122       Doctorate       Divorced    $80K - $120K          Blue
# 10123       Doctorate         Single         Unknown          Blue
# 10124       Doctorate        Married  Less than $40K          Blue
# 10125       Doctorate         Single  Less than $40K          Blue
# 10126       Doctorate        Married    $80K - $120K          Blue
#
#        Months_on_book  ...  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# 0                  39  ...                 1.335             1144
# 1                  34  ...                 1.405             1171
# 2                  27  ...                 2.204             1538
# 3                  56  ...                 1.831             1336
# 4                  33  ...                 1.608              931
# ...               ...  ...                   ...              ...
# 10122              33  ...                 0.656            15148
# 10123              36  ...                 0.912             8757
# 10124              33  ...                 0.749            14719
# 10125              15  ...                 0.645             8130
# 10126              33  ...                 0.709            14418
#
#        Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                  42                1.625                  0.061
# 1                  20                2.333                  0.760
# 2                  36                0.714                  0.048
# 3                  30                1.143                  0.788
# 4                  18                1.571                  0.152
# ...               ...                  ...                    ...
# 10122             111                0.790                  0.000
# 10123              68                0.789                  0.000
# 10124             115                0.855                  0.177
# 10125              74                0.897                  0.318
# 10126             104                0.677                  0.251
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000134
# 2                                               0.000086
# 3                                               0.000175
# 4                                               0.000069
# ...                                                  ...
# 10122                                           0.000083
# 10123                                           0.997800
# 10124                                           0.000438
# 10125                                           0.992120
# 10126                                           0.000141
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999870
# 2                                               0.999910
# 3                                               0.999830
# 4                                               0.999930
# ...                                                  ...
# 10122                                           0.999920
# 10123                                           0.002196
# 10124                                           0.999560
# 10125                                           0.007880
# 10126                                           0.999860
#
#        Customer_Age_y   Percent  Education_t
# 0                2013  0.198776  High School
# 1                2013  0.198776  High School
# 2                2013  0.198776  High School
# 3                2013  0.198776  High School
# 4                2013  0.198776  High School
# ...               ...       ...          ...
# 10122             451  0.044534       Others
# 10123             451  0.044534       Others
# 10124             451  0.044534       Others
# 10125             451  0.044534       Others
# 10126             451  0.044534       Others
#
# [10127 rows x 26 columns]

# %%
level.to_csv("Bank-t.csv")
